# %% [markdown]
# # <font color = Blue>G</font><font color = Red>o</font><font color = Orange>o</font><font color = Blue>g</font><font color = Green>l</font><font color = red>e</font> Play Store Analysis (<font color = BLUE>EDA</font>)

# %% [markdown]
# ![1_75SwvWQrspM0aKlN02uWTQ.jpeg](attachment:1_75SwvWQrspM0aKlN02uWTQ.jpeg)

# %% [markdown]
# ## The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market.
# ## Each app (row) has values for catergory, rating, size, and more. Another dataset contains customer reviews of the android apps.
# ## Explore and analyze the data to discover key factors responsible for app engagement and success.

# %% [markdown]
# ##   <font color = red>♦ Google play store dataset will involve various steps such as:</font>
# - 1.Importing Libraries
# - 2.Loading First Dataset:[Playstore](https://github.com/shubhamringole/Google-Play-Store-EDA-/blob/main/Play%20Store%20Data.csv "Click Me To Open Data Set")
#     * 2.1 DataCleaning(First Dataset:Playstore)
#     * 2.2 Handling Outliers(First Dataset: Playstore
#     * 2.3 Beginining Of Data Visualization of First Data Set : Playstore
# - 3.Loading Second DataSet: [User Reviews](https://github.com/shubhamringole/Google-Play-Store-EDA-/blob/18b04ea8c661105f00aac7a7f7f0f85512908fd0/User%20Reviews.csv 'Click Me To Open Data Set')
#     * 3.1 Data Cleaning (Second Dataset: User Reviews)
#     * 3.2 Data Visualization of Second Data set: User Reviews
# - 4 Merging Two Dataset (Playstore & User Reviews)
#     * 4.1 Begining of Data Visualization of two DataSets (Playsore & User Reviews)

# %% [markdown]
# ## 1. Importing Libraries

# %%
#Importing all Necessary Libraries Required for Data Analysis Pandas,Numpy and Matplotlib,Seaborn for Visualization
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import re
import plotly.express as px

# %%
# Importing Data Set
playstore_df = pd.read_csv("Play Store Data.csv")

# %% [markdown]
# ## 1.Basic Steps to follow
# - Examine Head and Tail of Data Set
# - Shape of Dataset
# - Cheking Data Type of All Columns
# - Summary

# %%
# Printing The First Five Rows Of The Data Set 
playstore_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
# Printing The Tail of Data set Which is Last 5 Rows
playstore_df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10836       Everyone          Education     July 25, 2017                1.48
# 10837       Everyone          Education      July 6, 2018                 1.0
# 10838       Everyone            Medical  January 20, 2017                 1.0
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device

# %%
# Printing The Shape oF Data Set
playstore_df.shape
# Out:
# (10841, 13)

# %% [markdown]
# We have total 10841 Rows and 13 Columns in the Data Set

# %%
# Checking Columns Name
playstore_df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# Printing the information of Dataset to get the better idea of Data Type and Memory use 
playstore_df.info(memory_usage='Deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# The info() function is used to print a concise summary of a DataFrame. This method prints information about a DataFrame including the index dtype and column dtypes, non-null values and memory usage.

# %%
# Printing the Describe Statistics 
playstore_df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %% [markdown]
# The describe() method is used for calculating some statistical data like percentile, mean and std of the numerical values of the Series or DataFrame. It analyzes both numeric and object series and also the DataFrame column sets of mixed data types.

# %% [markdown]
# ### 2. Now lets see which are the numerical columns
# - Rating
# - Reviews
# - Size
# - Installs
# - Price
#
# In The given Dataset Only the Rating Column is Numerical
# So we will start Converting the other Columns to numerical Data Type

# %% [markdown]
# ## 2.1 Checking Rating columns for any special character

# %% [markdown]
# - Lets check if there are aby outliers or special character in the columns

# %%
# lets plot a Box plot for rating colum to get some idea about the rating columns
playstore_df.boxplot(column=['Rating'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# From above observaion we can see there are values which are greater than 5. The raing of any apps has to be max 5 not greater than it so lets try to find oy this outlier

# %%
# Lets find out which row it is
playstore_df[playstore_df["Rating"]>5]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
# The category, Rating and Reviews Column have irregular data so i'am dropping this row having an index 10472
playstore_df.drop([10472], inplace = True)

# %% [markdown]
# ### 2.1 Conversion of Column:Reviews from object to float type

# %%
# Print the data typre of reviews column
playstore_df['Reviews'].dtype
# Out:
# dtype('O')

# %% [markdown]
# - Direct conversion of Reviews column may get some error if column contains any alphabets and special characters (non -digit)
# - So in order to check we can use isnumeric function (to check if it contains only digits or not) to determine the no of rows having irregular data for conversion

# %%
playstore_df[~playstore_df['Reviews'].str.isnumeric()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %% [markdown]
#  As we see there are  no string values in Reviews column we can now convert it into the numberi

# %%
# Converting the values from object to float
print(playstore_df["Reviews"].dtype)
playstore_df["Reviews"]=playstore_df["Reviews"].astype('int64')
playstore_df["Reviews"].dtype
# Out:
# object
# dtype('int64')
